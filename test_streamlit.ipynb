# %%
import streamlit as st
print("Streamlit version:", st.__version__)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8744/3391723067.py in <module>
# ----> 1 import streamlit as st
#       2 print("Streamlit version:", st.__version__)
#
# ~\anaconda3\lib\site-packages\streamlit\__init__.py in <module>
#      68 from streamlit import source_util as _source_util
#      69 from streamlit import string_util as _string_util
# ---> 70 from streamlit.delta_generator import DeltaGenerator as _DeltaGenerator
#      71 from streamlit.runtime.scriptrunner import (
#      72     add_script_run_ctx as _add_script_run_ctx,
#
# ~\anaconda3\lib\site-packages\streamlit\delta_generator.py in <module>
#      34
#      35 import streamlit as st
# ---> 36 from streamlit import cursor
#      37 from streamlit.runtime import caching, legacy_caching
#      38 from streamlit import type_util
#
# ...
